# %% [markdown]
# # Undirected scale-free networks

# %% [markdown]
# ## Dependencies

# %%
from netin.viz import handlers as vh
from netin import PA
from netin import PAH
from netin import PATC
from netin import PATCH

# %% [markdown]
# ## Network parameters

# %%
n = 2000
k = 2
f_m = 0.2
h_MM = 0.5
h_mm = 0.5
tc = 0.5
seed = 1234

# %% [markdown]
# ## Generation

# %%
# PA: Preferential attachment only
g_pa = PA(n=n, k=k, f_m=f_m, seed=seed)
g_pa.generate()
g_pa.info()
# Out:
# === Params ===
# n: 2000
# f_m: 0.2
# k: 2
# seed: 1234
# === Model ===
# Model: PA
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 4.006333112716675 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 2000
# - number of edges: 3996
# - minimum degree: 2
# - fraction of minority: 0.2
# - edge-type counts: Counter({'MM': 2584, 'Mm': 639, 'mM': 612, 'mm': 161})
# - density: 0.0019989994997498747
# - diameter: 7
# - average shortest path length: 4.3049904952476234
# - average degree: 3.996
# - degree assortativity: -0.0729413292184675
# - attribute assortativity (m): 0.009814216714187016
# - transitivity: 0.005679327248814316
# - average clustering: 0.017597328609007368

# %%
# PAH: Preferential attachment and homophily
g_pah = PAH(n=n, k=k, f_m=f_m, h_MM=h_MM, h_mm=h_mm, seed=seed)
g_pah.generate()
g_pah.info()
# Out:
# === Params ===
# n: 2000
# f_m: 0.2
# k: 2
# seed: 4019839154
# === Model ===
# Model: PAH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 5.52239203453064 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 2000
# - number of edges: 3996
# - minimum degree: 2
# - fraction of minority: 0.2
# - edge-type counts: Counter({'MM': 2551, 'mM': 649, 'Mm': 611, 'mm': 185})
# - density: 0.0019989994997498747
# - diameter: 8
# - average shortest path length: 4.285412206103052
# - average degree: 3.996
# - degree assortativity: -0.05842491816497617
# - attribute assortativity (m): 0.028942937649347817
# - transitivity: 0.007368140977097362
# - average clustering: 0.020343323162217215
# - Empirical homophily within majority: None
# - Empirical homophily within minority: None

# %%
# PATC: Preferential attachment and triadic closure
g_patc = PATC(n=n, k=k, f_m=f_m, tc=tc, seed=seed)
g_patc.generate()
g_patc.info()
# Out:
# === Params ===
# n: 2000
# f_m: 0.2
# tc: 0.5
# seed: 1234
# === Model ===
# Model: PATC
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 3.5552306175231934 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 2000
# - number of edges: 3996
# - minimum degree: 2
# - fraction of minority: 0.2
# - edge-type counts: Counter({'MM': 2604, 'Mm': 629, 'mM': 592, 'mm': 171})
# - density: 0.0019989994997498747
# - diameter: 9
# - average shortest path length: 4.535156578289144
# - average degree: 3.996
# - degree assortativity: -0.07032795439852507
# - attribute assortativity (m): 0.02888930885093885
# - transitivity: 0.06818029752213574
# - average clustering: 0.3720480918336517
# - Empirical triadic closure: None

# %%
# PATCH: Preferential attachment, homophily, and triadic closure
g_patch = PATCH(n=n, k=k, f_m=f_m, h_MM=h_MM, h_mm=h_mm, tc=tc, seed=seed)
g_patch.generate()
g_patch.info()
# Out:
# === Params ===
# n: 2000
# f_m: 0.2
# tc: 0.5
# k: 2
# seed: 1738966040
# === Model ===
# Model: PATCH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 4.606528997421265 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 2000
# - number of edges: 3996
# - minimum degree: 2
# - fraction of minority: 0.2
# - edge-type counts: Counter({'MM': 2674, 'Mm': 690, 'mM': 522, 'mm': 110})
# - density: 0.0019989994997498747
# - diameter: 9
# - average shortest path length: 4.580593296648324
# - average degree: 3.996
# - degree assortativity: -0.08462111086719974
# - attribute assortativity (m): -0.03112481264477471
# - transitivity: 0.06744779281421592
# - average clustering: 0.379862653390769
# - Empirical triadic closure: None
# - Empirical homophily within majority: None
# - Empirical homophily within minority: None

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Graph

# %%
graphs = [g_pa, g_pah, g_patc, g_patch]
vh.plot_graphs(graphs, cell_size=2)

# %% [markdown]
# ### Node attributes

# %%
md_pa = g_pa.get_node_metadata_as_dataframe(n_jobs=10)
md_pah = g_pah.get_node_metadata_as_dataframe(n_jobs=10)
md_patc = g_patc.get_node_metadata_as_dataframe(n_jobs=10)
md_patch = g_patch.get_node_metadata_as_dataframe(n_jobs=10)
# all into a list
degree_distributions = [md_pa, md_pah, md_patc, md_patch]
# Out:
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# #### Degree

# %%
vh.plot_distributions(degree_distributions, cell_size=2.5, sharex=True, sharey=True,
                      x='degree', hue='class_label', log_scale=(True,True))

# %%
vh.plot_distributions(degree_distributions, cell_size=2.5, sharex=True, sharey=True,
                      x='pagerank', hue='class_label', log_scale=(True,True))
