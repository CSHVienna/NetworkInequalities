# %% [markdown]
# # Undirected scale-free networks

# %% [markdown]
# ## Dependencies

# %%
# %load_ext autoreload
# %autoreload 2

from netin.viz import handlers as vh
from netin import PA
from netin import PAH
from netin import PATC
from netin import PATCH

# %% [markdown]
# ## Network parameters

# %%
n = 1000
k = 2
f_m = 0.1
h_MM = 0.9
h_mm = 0.9
tc = 0.8
seed = 1234

# %% [markdown]
# ## Generation

# %%
# PA: Preferential attachment only
g_pa = PA(n=n, k=k, f_m=f_m, seed=seed)
g_pa.generate()
g_pa.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# k: 2
# seed: 1234
# === Model ===
# Model: PA
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.0990195274353027 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 1000
# - number of edges: 1996
# - minimum degree: 2
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 1655, 'Mm': 180, 'mM': 141, 'mm': 20})
# - density: 0.003995995995995996
# - diameter: 8
# - average shortest path length: 4.154758758758759
# - average degree: 3.992
# - degree assortativity: -0.07205891167684375
# - attribute assortativity (m): 0.022397926137728272
# - transitivity: 0.00993320774105155
# - average clustering: 0.022453234341499925

# %%
# PAH: Preferential attachment and homophily
g_pah = PAH(n=n, k=k, f_m=f_m, h_MM=h_MM, h_mm=h_mm, seed=seed)
g_pah.generate()
g_pah.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# k: 2
# h_MM: 0.9
# h_mm: 0.9
# mixing matrix:
# [[0.9 0.1]
#  [0.1 0.9]]
# seed: 1234
# === Model ===
# Model: PAH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.5099389553070068 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 1000
# - number of edges: 1996
# - minimum degree: 2
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 1784, 'Mm': 133, 'mm': 67, 'mM': 12})
# - density: 0.003995995995995996
# - diameter: 7
# - average shortest path length: 4.094460460460461
# - average degree: 3.992
# - degree assortativity: -0.1204271602746538
# - attribute assortativity (m): 0.4412347588198785
# - transitivity: 0.009613869188337273
# - average clustering: 0.0272429544386381
# - Empirical homophily within majority: None
# - Empirical homophily within minority: None

# %%
# PATC: Preferential attachment and triadic closure
g_patc = PATC(n=n, k=k, f_m=f_m, tc=tc, seed=seed)
g_patc.generate()
g_patc.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# k: 2
# tc: 0.8
# seed: 1234
# === Model ===
# Model: PATC
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 0.8915791511535645 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 1000
# - number of edges: 1996
# - minimum degree: 2
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 1623, 'Mm': 183, 'mM': 173, 'mm': 17})
# - density: 0.003995995995995996
# - diameter: 10
# - average shortest path length: 4.642116116116116
# - average degree: 3.992
# - degree assortativity: -0.10705617464659427
# - attribute assortativity (m): -0.011654493942112114
# - transitivity: 0.1287202778519904
# - average clustering: 0.6004463626617123
# - Empirical triadic closure: None

# %%
# PATCH: Preferential attachment, homophily, and triadic closure
g_patch = PATCH(n=n, k=k, f_m=f_m, h_MM=h_MM, h_mm=h_mm, tc=tc, seed=seed)
g_patch.generate()
g_patch.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# k: 2
# h_MM: 0.9
# h_mm: 0.9
# mixing matrix:
# [[0.9 0.1]
#  [0.1 0.9]]
# tc: 0.8
# seed: 1234
# === Model ===
# Model: PATCH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.1295413970947266 (secs)
# === Computed ===
# - is directed: False
# - number of nodes: 1000
# - number of edges: 1996
# - minimum degree: 2
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 1744, 'Mm': 155, 'mM': 52, 'mm': 45})
# - density: 0.003995995995995996
# - diameter: 10
# - average shortest path length: 4.708366366366366
# - average degree: 3.992
# - degree assortativity: -0.11255381227880877
# - attribute assortativity (m): 0.2470086521507371
# - transitivity: 0.13287678798254818
# - average clustering: 0.5922042497216702
# - Empirical homophily within majority: None
# - Empirical homophily within minority: None
# - Empirical triadic closure: None

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Graph

# %%
graphs = [g_pa, g_pah, g_patc, g_patch]
vh.plot_graphs(graphs, cell_size=2, share_pos=False)

# %% [markdown]
# ### Node attributes

# %%
md_pa = g_pa.get_node_metadata_as_dataframe(n_jobs=10)
md_pah = g_pah.get_node_metadata_as_dataframe(n_jobs=10)
md_patc = g_patc.get_node_metadata_as_dataframe(n_jobs=10)
md_patch = g_patch.get_node_metadata_as_dataframe(n_jobs=10)
# Out:
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# see example of genereate metadata 
md_pa.head()
# Out:
#    node class_label  degree in_degree out_degree  clustering  betweenness
# 0     0           M      50       NaN        NaN    0.012245     0.147902  \
# 1     1           M      10       NaN        NaN    0.066667     0.010750
# 2     2           M      27       NaN        NaN    0.008547     0.053655
# 3     3           M      70       NaN        NaN    0.009938     0.221822
# 4     4           M      42       NaN        NaN    0.009292     0.100789
#
#    closeness  eigenvector  pagerank
# 0   0.359870     0.240071  0.010447
# 1   0.296000     0.080638  0.002257
# 2   0.331014     0.124816  0.005822
# 3   0.386460     0.490662  0.014882
# 4   0.348326     0.210229  0.008940

# %%
# all into a list
distributions = [md_pa, md_pah, md_patc, md_patch]

# %% [markdown]
# #### Degree

# %%
vh.plot_pdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='degree', hue='class_label', 
                          log_scale=(True,True),common_norm=True)

# %%
vh.plot_pdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='degree', hue='class_label', 
                          log_scale=(True,True),common_norm=False)

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='degree', hue='class_label', 
                          log_scale=(True,False))

# %%
vh.plot_ccdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='degree', hue='class_label', 
                          log_scale=(True,False))

# %% [markdown]
# #### Clustering

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='clustering', hue='class_label', 
                          log_scale=(False,False))

# %% [markdown]
# #### PageRank

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='pagerank', hue='class_label',
                          log_scale=(False,False))
