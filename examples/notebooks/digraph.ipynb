# %% [markdown]
# # Directed scale-free networks

# %% [markdown]
# ## Dependencies

# %%
# %load_ext autoreload
# %autoreload 2

from netin.viz import handlers as vh
from netin import PA
from netin import DPA
from netin import DH
from netin import DPAH

# %% [markdown]
# ## Network parameters

# %%
n = 1000
f_m = 0.1
d = 0.001
h_MM = 0.9
h_mm = 0.9
plo_M = 2.0
plo_m = 2.0
seed = 1234

# %% [markdown]
# ## Generation

# %%
# DPA: Preferential attachment only
g_dpa = DPA(n=n, f_m=f_m, d=d, plo_M=plo_M, plo_m=plo_m, seed=seed)
g_dpa.generate()
g_dpa.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# d: 0.001 (expected edges: 999)
# plo_M: 2.0
# plo_m: 2.0
# seed: 1234
# === Model ===
# Model: DPA
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.1202194690704346 (secs)
# === Computed ===
# - is directed: True
# - number of nodes: 1000
# - number of edges: 999
# - minimum degree: 0
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 716, 'Mm': 167, 'mM': 94, 'mm': 22})
# - density: 0.001
# - diameter: <Found infinite path length because the digraph is not strongly connected>
# - average shortest path length: <Graph is not strongly connected.>
# - average degree: 1.998
# - degree assortativity: -0.3423375276172191
# - attribute assortativity (m): 0.0004140358140972446
# - transitivity: 0.0047598316644899144
# - average clustering: 0.03360729788691975
# Calculating best minimal value for power law fit
# - M: alpha=2.230785053837675, sigma=0.2685793177824497, min=5.0, max=None
# ...

# %%
# DH: Homophily only
g_dh = DH(n=n, f_m=f_m, d=d, h_MM=h_MM, h_mm=h_mm, plo_M=plo_M, plo_m=plo_m, seed=seed)
g_dh.generate()
g_dh.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# d: 0.001 (expected edges: 999)
# plo_M: 2.0
# plo_m: 2.0
# h_MM: 0.9
# h_mm: 0.9
# mixing matrix:
# [[0.9 0.1]
#  [0.1 0.9]]
# seed: 1234
# === Model ===
# Model: DH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.1158270835876465 (secs)
# === Computed ===
# - is directed: True
# - number of nodes: 1000
# - number of edges: 999
# - minimum degree: 0
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 856, 'mM': 72, 'mm': 62, 'Mm': 9})
# - density: 0.001
# - diameter: <Found infinite path length because the digraph is not strongly connected>
# - average shortest path length: <Graph is not strongly connected.>
# - average degree: 1.998
# - degree assortativity: -0.05131887908203784
# - attribute assortativity (m): 0.564405949388212
# - transitivity: 0.0011209910320717435
# - average clustering: 0.01732507611265676
# Calculating best minimal value for power law fit
# ...

# %%
# DPAH: Preferential attachment and homophily
g_dpah = DPAH(n=n, f_m=f_m, d=d, h_MM=h_MM, h_mm=h_mm, plo_M=plo_M, plo_m=plo_m, seed=seed)
g_dpah.generate()
g_dpah.info()
# Out:
# === Params ===
# n: 1000
# f_m: 0.1
# d: 0.001 (expected edges: 999)
# plo_M: 2.0
# plo_m: 2.0
# h_MM: 0.9
# h_mm: 0.9
# mixing matrix:
# [[0.9 0.1]
#  [0.1 0.9]]
# seed: 1234
# === Model ===
# Model: DPAH
# Class attribute: m
# Class values: [0, 1]
# Class labels: ['M', 'm']
# Generation time: 1.4217090606689453 (secs)
# === Computed ===
# - is directed: True
# - number of nodes: 1000
# - number of edges: 999
# - minimum degree: 0
# - fraction of minority: 0.1
# - edge-type counts: Counter({'MM': 859, 'mM': 124, 'mm': 10, 'Mm': 6})
# - density: 0.001
# - diameter: <Found infinite path length because the digraph is not strongly connected>
# - average shortest path length: <Graph is not strongly connected.>
# - average degree: 1.998
# - degree assortativity: -0.36728720701572803
# - attribute assortativity (m): 0.107802860636704
# - transitivity: 0.006980636816677445
# - average clustering: 0.036041365923469015
# Calculating best minimal value for power law fit
# ...

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Graph

# %%
graphs = [g_dpa, g_dh, g_dpah]
vh.plot_graphs(graphs, cell_size=2, share_pos=False)

# %% [markdown]
# ### Node attributes

# %%
md_dpa = g_dpa.get_node_metadata_as_dataframe(n_jobs=10)
md_dh = g_dh.get_node_metadata_as_dataframe(n_jobs=10)
md_dpah = g_dpah.get_node_metadata_as_dataframe(n_jobs=10)
# Out:
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]
# QUEUEING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# see example of genereate metadata 
md_dpa.head()
# Out:
#    node class_label degree  in_degree  out_degree  clustering  betweenness
# 0     0           M    NaN          2           0    0.000000     0.000000  \
# 1     1           M    NaN          1           0    0.000000     0.000000
# 2     2           M    NaN          0           0    0.000000     0.000000
# 3     3           M    NaN          2           1    0.166667     0.000001
# 4     4           M    NaN          0           1    0.000000     0.000000
#
#    closeness   eigenvector  pagerank
# 0   0.002002  1.701320e-14  0.000788
# 1   0.001001  2.283852e-14  0.000736
# 2   0.000000  3.518903e-16  0.000734
# 3   0.002002  4.794643e-14  0.001048
# 4   0.000000 -3.922048e-17  0.000734

# %%
# all into a list
distributions = [md_dpa, md_dh, md_dpah]

# %% [markdown]
# #### In-degree

# %%
vh.plot_pdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='in_degree', hue='class_label', 
                          log_scale=(True,True),common_norm=True)

# %%
vh.plot_pdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='in_degree', hue='class_label', 
                          log_scale=(True,True),common_norm=False)

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='in_degree', hue='class_label', 
                          log_scale=(True,False))

# %%
vh.plot_ccdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='in_degree', hue='class_label', 
                          log_scale=(True,True))

# %% [markdown]
# #### Out-degree

# %%
vh.plot_pdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='out_degree', hue='class_label', 
                          log_scale=(True,True),common_norm=False)

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='out_degree', hue='class_label', 
                          log_scale=(True,False))

# %% [markdown]
# #### Clustering

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='clustering', hue='class_label', 
                          log_scale=(False,False))

# %% [markdown]
# #### PageRank

# %%
vh.plot_cdf_distribution(distributions, 
                          cell_size=2, sharex=True, sharey=True,
                          x='pagerank', hue='class_label',
                          log_scale=(True,False))
